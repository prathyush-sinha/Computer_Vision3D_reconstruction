# %% [markdown]
# # Demo: 3D Reconstruction Pipeline
#
# This notebook demonstrates the cleaned project workflow. The original exploratory run is preserved in `main.ipynb`; this notebook shows how to use the modular `src/` code.

# %% [markdown]
# ## 1. Configure paths
#
# Update `images_dir` to point to your multi-view image directory.

# %%
from src.config import build_config

images_dir = 'datasets'
outputs_dir = 'outputs/demo-front'

cfg = build_config(images_dir, outputs_dir, feature_conf='sift', matcher_conf='adalam', validate_paths=False)
cfg

# %% [markdown]
# ## 2. Run the pipeline
#
# Uncomment the lines below after installing HLoc/COLMAP and pointing `images_dir` to a real image folder.

# %%
# from src.extract_features import list_images, extract_local_features
# from src.match_features import match_local_features
# from src.reconstruct import run_sfm_reconstruction

# image_list = list_images(cfg.images)
# extract_local_features(cfg, image_list=image_list)
# match_local_features(cfg, image_list=image_list)
# model = run_sfm_reconstruction(cfg, image_list=image_list)
# print(model)

# %% [markdown]
# ## 3. Known result from original run
#
# | Metric | Value |
# |---|---:|
# | Input images | 104 |
# | Registered images | 27 |
# | Sparse 3D points | 2,432 |
# | Mean reprojection error | 1.25835 px |
